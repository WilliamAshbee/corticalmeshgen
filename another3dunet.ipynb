# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/corticalmeshgen/blob/main/another3dunet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/davidiommi/Pytorch-Unet3D-single_channel/blob/master/UNet.py

# %%
# !pip install torchsummaryX
# Out:
# Requirement already satisfied: torchsummaryX in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.3.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torchsummaryX) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchsummaryX) (3.10.0.2)

# %%
a = None
model = None

# %%
from torch.nn import Module, Sequential
from torch.nn import Conv3d, ConvTranspose3d, BatchNorm3d, MaxPool3d, AvgPool1d, Dropout3d
from torch.nn import ReLU, Sigmoid
import torch


class UNet(Module):
    # __                            __
    #  1|__   ________________   __|1
    #     2|__  ____________  __|2
    #        3|__  ______  __|3
    #           4|__ __ __|4
    # The convolution operations on either side are residual subject to 1*1 Convolution for channel homogeneity

    def __init__(self, num_channels=1, feat_channels=[64, 256, 256, 512, 1024], residual='conv'):
        # residual: conv for residual input x through 1*1 conv across every layer for downsampling, None for removal of residuals

        super(UNet, self).__init__()

        # Encoder downsamplers
        self.pool1 = MaxPool3d((2, 2, 2))
        self.pool2 = MaxPool3d((2, 2, 2))
        self.pool3 = MaxPool3d((2, 2, 2))
        self.pool4 = MaxPool3d((2, 2, 2))

        # Encoder convolutions
        self.conv_blk1 = Conv3D_Block(num_channels, feat_channels[0], residual=residual)
        self.conv_blk2 = Conv3D_Block(feat_channels[0], feat_channels[1], residual=residual)
        self.conv_blk3 = Conv3D_Block(feat_channels[1], feat_channels[2], residual=residual)
        self.conv_blk4 = Conv3D_Block(feat_channels[2], feat_channels[3], residual=residual)
        self.conv_blk5 = Conv3D_Block(feat_channels[3], feat_channels[4], residual=residual)

        # Decoder convolutions
        self.dec_conv_blk4 = Conv3D_Block(2 * feat_channels[3], feat_channels[3], residual=residual)
        self.dec_conv_blk3 = Conv3D_Block(2 * feat_channels[2], feat_channels[2], residual=residual)
        self.dec_conv_blk2 = Conv3D_Block(2 * feat_channels[1], feat_channels[1], residual=residual)
        self.dec_conv_blk1 = Conv3D_Block(2 * feat_channels[0], feat_channels[0], residual=residual)

        # Decoder upsamplers
        self.deconv_blk4 = Deconv3D_Block(feat_channels[4], feat_channels[3])
        self.deconv_blk3 = Deconv3D_Block(feat_channels[3], feat_channels[2])
        self.deconv_blk2 = Deconv3D_Block(feat_channels[2], feat_channels[1])
        self.deconv_blk1 = Deconv3D_Block(feat_channels[1], feat_channels[0])

        # Final 1*1 Conv Segmentation map
        self.one_conv = Conv3d(feat_channels[0], num_channels, kernel_size=1, stride=1, padding=0, bias=True)

        # Activation function
        self.sigmoid = Sigmoid()

    def forward(self, x):
        # Encoder part
        print('x',x.shape)
        x1 = self.conv_blk1(x)


        print('x1',x1.shape)
        x_low1 = self.pool1(x1)
        x2 = self.conv_blk2(x_low1)
        
        print('x2',x2.shape)
        
        x_low2 = self.pool2(x2)
        x3 = self.conv_blk3(x_low2)

        print('x3',x3.shape)
        x_low3 = self.pool3(x3)
        x4 = self.conv_blk4(x_low3)

        print('x4',x4.shape)
        x_low4 = self.pool4(x4)
        base = self.conv_blk5(x_low4)

        # Decoder part
        
        d4 = torch.cat([self.deconv_blk4(base), x4], dim=1)
        d_high4 = self.dec_conv_blk4(d4)
        
        print('d_high4',d_high4.shape)
        d3 = torch.cat([self.deconv_blk3(d_high4), x3], dim=1)
        d_high3 = self.dec_conv_blk3(d3)
        d_high3 = Dropout3d(p=0.5)(d_high3)

        print('d_high3',d_high3.shape)
        
        d2 = torch.cat([self.deconv_blk2(d_high3), x2], dim=1)
        d_high2 = self.dec_conv_blk2(d2)
        d_high2 = Dropout3d(p=0.5)(d_high2)

        print('d_high2',d_high2.shape)
        
        d1 = torch.cat([self.deconv_blk1(d_high2), x1], dim=1)
        d_high1 = self.dec_conv_blk1(d1)

        print('d_high1',d_high1.shape)
        
        seg = self.sigmoid(self.one_conv(d_high1))
        print('seg',seg.shape)
        
        return seg


class Conv3D_Block(Module):

    def __init__(self, inp_feat, out_feat, kernel=3, stride=1, padding=1, residual=None):

        super(Conv3D_Block, self).__init__()

        self.conv1 = Sequential(
            Conv3d(inp_feat, out_feat, kernel_size=kernel,
                   stride=stride, padding=padding, bias=True),
            BatchNorm3d(out_feat),
            ReLU())

        self.conv2 = Sequential(
            Conv3d(out_feat, out_feat, kernel_size=kernel,
                   stride=stride, padding=padding, bias=True),
            BatchNorm3d(out_feat),
            ReLU())

        self.residual = residual

        if self.residual is not None:
            self.residual_upsampler = Conv3d(inp_feat, out_feat, kernel_size=1, bias=False)

    def forward(self, x):

        res = x

        if not self.residual:
            return self.conv2(self.conv1(x))
        else:
            return self.conv2(self.conv1(x)) + self.residual_upsampler(res)


class Deconv3D_Block(Module):

    def __init__(self, inp_feat, out_feat, kernel=3, stride=2, padding=1):
        super(Deconv3D_Block, self).__init__()

        self.deconv = Sequential(
            ConvTranspose3d(inp_feat, out_feat, kernel_size=(kernel, kernel, kernel),
                            stride=(stride, stride, stride), padding=(padding, padding, padding), output_padding=1, bias=True),
            ReLU())

    def forward(self, x):
        return self.deconv(x)


class ChannelPool3d(AvgPool1d):

    def __init__(self, kernel_size, stride, padding):
        super(ChannelPool3d, self).__init__(kernel_size, stride, padding)
        self.pool_1d = AvgPool1d(self.kernel_size, self.stride, self.padding, self.ceil_mode)

    def forward(self, inp):
        n, c, d, w, h = inp.size()
        inp = inp.view(n, c, d * w * h).permute(0, 2, 1)
        pooled = self.pool_1d(inp)
        c = int(c / self.kernel_size[0])
        return inp.view(n, c, d, w, h)


if __name__ == '__main__':
    import time
    import torch
    from torch.autograd import Variable
    from torchsummaryX import summary

    torch.cuda.set_device(0)
    net =UNet(residual='pool').cuda().eval()

    data = Variable(torch.randn(1, 1, 128, 128, 32)).cuda()

    out = net(data)

    summary(net,data)
    print("out size: {}".format(out.size()))
# Out:
# x torch.Size([1, 1, 128, 128, 32])
# x1 torch.Size([1, 64, 128, 128, 32])
# x2 torch.Size([1, 256, 64, 64, 16])
# x3 torch.Size([1, 256, 32, 32, 8])
# x4 torch.Size([1, 512, 16, 16, 4])
# d_high4 torch.Size([1, 512, 16, 16, 4])
# d_high3 torch.Size([1, 256, 32, 32, 8])
# d_high2 torch.Size([1, 256, 64, 64, 16])
# d_high1 torch.Size([1, 64, 128, 128, 32])
# seg torch.Size([1, 1, 128, 128, 32])
# x torch.Size([1, 1, 128, 128, 32])
# x1 torch.Size([1, 64, 128, 128, 32])
# x2 torch.Size([1, 256, 64, 64, 16])
# x3 torch.Size([1, 256, 32, 32, 8])
# x4 torch.Size([1, 512, 16, 16, 4])
# d_high4 torch.Size([1, 512, 16, 16, 4])
# d_high3 torch.Size([1, 256, 32, 32, 8])
# d_high2 torch.Size([1, 256, 64, 64, 16])
# d_high1 torch.Size([1, 64, 128, 128, 32])
# seg torch.Size([1, 1, 128, 128, 32])
# ==================================================================================================================
#                                                      Kernel Shape  \
# Layer
# 0_conv_blk1.conv1.Conv3d_0                       [1, 64, 3, 3, 3]
# 1_conv_blk1.conv1.BatchNorm3d_1                              [64]
# 2_conv_blk1.conv1.ReLU_2                                        -
# 3_conv_blk1.conv2.Conv3d_0                      [64, 64, 3, 3, 3]
# 4_conv_blk1.conv2.BatchNorm3d_1                              [64]
# 5_conv_blk1.conv2.ReLU_2                                        -
# 6_conv_blk1.Conv3d_residual_upsampler            [1, 64, 1, 1, 1]
# 7_pool1                                                         -
# 8_conv_blk2.conv1.Conv3d_0                     [64, 256, 3, 3, 3]
# 9_conv_blk2.conv1.BatchNorm3d_1                             [256]
# 10_conv_blk2.conv1.ReLU_2                                       -
# 11_conv_blk2.conv2.Conv3d_0                   [256, 256, 3, 3, 3]
# 12_conv_blk2.conv2.BatchNorm3d_1                            [256]
# 13_conv_blk2.conv2.ReLU_2                                       -
# 14_conv_blk2.Conv3d_residual_upsampler         [64, 256, 1, 1, 1]
# 15_pool2                                                        -
# 16_conv_blk3.conv1.Conv3d_0                   [256, 256, 3, 3, 3]
# 17_conv_blk3.conv1.BatchNorm3d_1                            [256]
# 18_conv_blk3.conv1.ReLU_2                                       -
# 19_conv_blk3.conv2.Conv3d_0                   [256, 256, 3, 3, 3]
# 20_conv_blk3.conv2.BatchNorm3d_1                            [256]
# 21_conv_blk3.conv2.ReLU_2                                       -
# 22_conv_blk3.Conv3d_residual_upsampler        [256, 256, 1, 1, 1]
# 23_pool3                                                        -
# 24_conv_blk4.conv1.Conv3d_0                   [256, 512, 3, 3, 3]
# 25_conv_blk4.conv1.BatchNorm3d_1                            [512]
# 26_conv_blk4.conv1.ReLU_2                                       -
# 27_conv_blk4.conv2.Conv3d_0                   [512, 512, 3, 3, 3]
# 28_conv_blk4.conv2.BatchNorm3d_1                            [512]
# 29_conv_blk4.conv2.ReLU_2                                       -
# 30_conv_blk4.Conv3d_residual_upsampler        [256, 512, 1, 1, 1]
# 31_pool4                                                        -
# 32_conv_blk5.conv1.Conv3d_0                  [512, 1024, 3, 3, 3]
# 33_conv_blk5.conv1.BatchNorm3d_1                           [1024]
# 34_conv_blk5.conv1.ReLU_2                                       -
# 35_conv_blk5.conv2.Conv3d_0                 [1024, 1024, 3, 3, 3]
# 36_conv_blk5.conv2.BatchNorm3d_1                           [1024]
# 37_conv_blk5.conv2.ReLU_2                                       -
# 38_conv_blk5.Conv3d_residual_upsampler       [512, 1024, 1, 1, 1]
# 39_deconv_blk4.deconv.ConvTranspose3d_0      [512, 1024, 3, 3, 3]
# 40_deconv_blk4.deconv.ReLU_1                                    -
# 41_dec_conv_blk4.conv1.Conv3d_0              [1024, 512, 3, 3, 3]
# 42_dec_conv_blk4.conv1.BatchNorm3d_1                        [512]
# 43_dec_conv_blk4.conv1.ReLU_2                                   -
# 44_dec_conv_blk4.conv2.Conv3d_0               [512, 512, 3, 3, 3]
# 45_dec_conv_blk4.conv2.BatchNorm3d_1                        [512]
# 46_dec_conv_blk4.conv2.ReLU_2                                   -
# 47_dec_conv_blk4.Conv3d_residual_upsampler   [1024, 512, 1, 1, 1]
# 48_deconv_blk3.deconv.ConvTranspose3d_0       [256, 512, 3, 3, 3]
# 49_deconv_blk3.deconv.ReLU_1                                    -
# 50_dec_conv_blk3.conv1.Conv3d_0               [512, 256, 3, 3, 3]
# 51_dec_conv_blk3.conv1.BatchNorm3d_1                        [256]
# 52_dec_conv_blk3.conv1.ReLU_2                                   -
# 53_dec_conv_blk3.conv2.Conv3d_0               [256, 256, 3, 3, 3]
# 54_dec_conv_blk3.conv2.BatchNorm3d_1                        [256]
# 55_dec_conv_blk3.conv2.ReLU_2                                   -
# 56_dec_conv_blk3.Conv3d_residual_upsampler    [512, 256, 1, 1, 1]
# 57_deconv_blk2.deconv.ConvTranspose3d_0       [256, 256, 3, 3, 3]
# 58_deconv_blk2.deconv.ReLU_1                                    -
# 59_dec_conv_blk2.conv1.Conv3d_0               [512, 256, 3, 3, 3]
# 60_dec_conv_blk2.conv1.BatchNorm3d_1                        [256]
# 61_dec_conv_blk2.conv1.ReLU_2                                   -
# 62_dec_conv_blk2.conv2.Conv3d_0               [256, 256, 3, 3, 3]
# 63_dec_conv_blk2.conv2.BatchNorm3d_1                        [256]
# 64_dec_conv_blk2.conv2.ReLU_2                                   -
# 65_dec_conv_blk2.Conv3d_residual_upsampler    [512, 256, 1, 1, 1]
# 66_deconv_blk1.deconv.ConvTranspose3d_0        [64, 256, 3, 3, 3]
# 67_deconv_blk1.deconv.ReLU_1                                    -
# 68_dec_conv_blk1.conv1.Conv3d_0                [128, 64, 3, 3, 3]
# 69_dec_conv_blk1.conv1.BatchNorm3d_1                         [64]
# 70_dec_conv_blk1.conv1.ReLU_2                                   -
# 71_dec_conv_blk1.conv2.Conv3d_0                 [64, 64, 3, 3, 3]
# 72_dec_conv_blk1.conv2.BatchNorm3d_1                         [64]
# 73_dec_conv_blk1.conv2.ReLU_2                                   -
# 74_dec_conv_blk1.Conv3d_residual_upsampler     [128, 64, 1, 1, 1]
# 75_one_conv                                      [64, 1, 1, 1, 1]
# 76_sigmoid                                                      -
#
#                                                      Output Shape      Params  \
# Layer
# 0_conv_blk1.conv1.Conv3d_0                  [1, 64, 128, 128, 32]      1.792k
# 1_conv_blk1.conv1.BatchNorm3d_1             [1, 64, 128, 128, 32]       128.0
# 2_conv_blk1.conv1.ReLU_2                    [1, 64, 128, 128, 32]           -
# 3_conv_blk1.conv2.Conv3d_0                  [1, 64, 128, 128, 32]    110.656k
# 4_conv_blk1.conv2.BatchNorm3d_1             [1, 64, 128, 128, 32]       128.0
# 5_conv_blk1.conv2.ReLU_2                    [1, 64, 128, 128, 32]           -
# 6_conv_blk1.Conv3d_residual_upsampler       [1, 64, 128, 128, 32]        64.0
# 7_pool1                                       [1, 64, 64, 64, 16]           -
# 8_conv_blk2.conv1.Conv3d_0                   [1, 256, 64, 64, 16]    442.624k
# 9_conv_blk2.conv1.BatchNorm3d_1              [1, 256, 64, 64, 16]       512.0
# 10_conv_blk2.conv1.ReLU_2                    [1, 256, 64, 64, 16]           -
# 11_conv_blk2.conv2.Conv3d_0                  [1, 256, 64, 64, 16]   1.769728M
# 12_conv_blk2.conv2.BatchNorm3d_1             [1, 256, 64, 64, 16]       512.0
# 13_conv_blk2.conv2.ReLU_2                    [1, 256, 64, 64, 16]           -
# 14_conv_blk2.Conv3d_residual_upsampler       [1, 256, 64, 64, 16]     16.384k
# 15_pool2                                      [1, 256, 32, 32, 8]           -
# 16_conv_blk3.conv1.Conv3d_0                   [1, 256, 32, 32, 8]   1.769728M
# 17_conv_blk3.conv1.BatchNorm3d_1              [1, 256, 32, 32, 8]       512.0
# 18_conv_blk3.conv1.ReLU_2                     [1, 256, 32, 32, 8]           -
# 19_conv_blk3.conv2.Conv3d_0                   [1, 256, 32, 32, 8]   1.769728M
# 20_conv_blk3.conv2.BatchNorm3d_1              [1, 256, 32, 32, 8]       512.0
# 21_conv_blk3.conv2.ReLU_2                     [1, 256, 32, 32, 8]           -
# 22_conv_blk3.Conv3d_residual_upsampler        [1, 256, 32, 32, 8]     65.536k
# 23_pool3                                      [1, 256, 16, 16, 4]           -
# 24_conv_blk4.conv1.Conv3d_0                   [1, 512, 16, 16, 4]   3.539456M
# 25_conv_blk4.conv1.BatchNorm3d_1              [1, 512, 16, 16, 4]      1.024k
# 26_conv_blk4.conv1.ReLU_2                     [1, 512, 16, 16, 4]           -
# 27_conv_blk4.conv2.Conv3d_0                   [1, 512, 16, 16, 4]     7.0784M
# 28_conv_blk4.conv2.BatchNorm3d_1              [1, 512, 16, 16, 4]      1.024k
# 29_conv_blk4.conv2.ReLU_2                     [1, 512, 16, 16, 4]           -
# 30_conv_blk4.Conv3d_residual_upsampler        [1, 512, 16, 16, 4]    131.072k
# 31_pool4                                        [1, 512, 8, 8, 2]           -
# 32_conv_blk5.conv1.Conv3d_0                    [1, 1024, 8, 8, 2]    14.1568M
# 33_conv_blk5.conv1.BatchNorm3d_1               [1, 1024, 8, 8, 2]      2.048k
# 34_conv_blk5.conv1.ReLU_2                      [1, 1024, 8, 8, 2]           -
# 35_conv_blk5.conv2.Conv3d_0                    [1, 1024, 8, 8, 2]  28.312576M
# 36_conv_blk5.conv2.BatchNorm3d_1               [1, 1024, 8, 8, 2]      2.048k
# 37_conv_blk5.conv2.ReLU_2                      [1, 1024, 8, 8, 2]           -
# 38_conv_blk5.Conv3d_residual_upsampler         [1, 1024, 8, 8, 2]    524.288k
# 39_deconv_blk4.deconv.ConvTranspose3d_0       [1, 512, 16, 16, 4]  14.156288M
# 40_deconv_blk4.deconv.ReLU_1                  [1, 512, 16, 16, 4]           -
# 41_dec_conv_blk4.conv1.Conv3d_0               [1, 512, 16, 16, 4]  14.156288M
# 42_dec_conv_blk4.conv1.BatchNorm3d_1          [1, 512, 16, 16, 4]      1.024k
# 43_dec_conv_blk4.conv1.ReLU_2                 [1, 512, 16, 16, 4]           -
# 44_dec_conv_blk4.conv2.Conv3d_0               [1, 512, 16, 16, 4]     7.0784M
# 45_dec_conv_blk4.conv2.BatchNorm3d_1          [1, 512, 16, 16, 4]      1.024k
# 46_dec_conv_blk4.conv2.ReLU_2                 [1, 512, 16, 16, 4]           -
# 47_dec_conv_blk4.Conv3d_residual_upsampler    [1, 512, 16, 16, 4]    524.288k
# 48_deconv_blk3.deconv.ConvTranspose3d_0       [1, 256, 32, 32, 8]     3.5392M
# 49_deconv_blk3.deconv.ReLU_1                  [1, 256, 32, 32, 8]           -
# 50_dec_conv_blk3.conv1.Conv3d_0               [1, 256, 32, 32, 8]     3.5392M
# 51_dec_conv_blk3.conv1.BatchNorm3d_1          [1, 256, 32, 32, 8]       512.0
# 52_dec_conv_blk3.conv1.ReLU_2                 [1, 256, 32, 32, 8]           -
# 53_dec_conv_blk3.conv2.Conv3d_0               [1, 256, 32, 32, 8]   1.769728M
# 54_dec_conv_blk3.conv2.BatchNorm3d_1          [1, 256, 32, 32, 8]       512.0
# 55_dec_conv_blk3.conv2.ReLU_2                 [1, 256, 32, 32, 8]           -
# 56_dec_conv_blk3.Conv3d_residual_upsampler    [1, 256, 32, 32, 8]    131.072k
# 57_deconv_blk2.deconv.ConvTranspose3d_0      [1, 256, 64, 64, 16]   1.769728M
# 58_deconv_blk2.deconv.ReLU_1                 [1, 256, 64, 64, 16]           -
# 59_dec_conv_blk2.conv1.Conv3d_0              [1, 256, 64, 64, 16]     3.5392M
# 60_dec_conv_blk2.conv1.BatchNorm3d_1         [1, 256, 64, 64, 16]       512.0
# 61_dec_conv_blk2.conv1.ReLU_2                [1, 256, 64, 64, 16]           -
# 62_dec_conv_blk2.conv2.Conv3d_0              [1, 256, 64, 64, 16]   1.769728M
# 63_dec_conv_blk2.conv2.BatchNorm3d_1         [1, 256, 64, 64, 16]       512.0
# 64_dec_conv_blk2.conv2.ReLU_2                [1, 256, 64, 64, 16]           -
# 65_dec_conv_blk2.Conv3d_residual_upsampler   [1, 256, 64, 64, 16]    131.072k
# 66_deconv_blk1.deconv.ConvTranspose3d_0     [1, 64, 128, 128, 32]    442.432k
# 67_deconv_blk1.deconv.ReLU_1                [1, 64, 128, 128, 32]           -
# 68_dec_conv_blk1.conv1.Conv3d_0             [1, 64, 128, 128, 32]    221.248k
# 69_dec_conv_blk1.conv1.BatchNorm3d_1        [1, 64, 128, 128, 32]       128.0
# 70_dec_conv_blk1.conv1.ReLU_2               [1, 64, 128, 128, 32]           -
# 71_dec_conv_blk1.conv2.Conv3d_0             [1, 64, 128, 128, 32]    110.656k
# 72_dec_conv_blk1.conv2.BatchNorm3d_1        [1, 64, 128, 128, 32]       128.0
# 73_dec_conv_blk1.conv2.ReLU_2               [1, 64, 128, 128, 32]           -
# 74_dec_conv_blk1.Conv3d_residual_upsampler  [1, 64, 128, 128, 32]      8.192k
# 75_one_conv                                  [1, 1, 128, 128, 32]        65.0
# 76_sigmoid                                   [1, 1, 128, 128, 32]           -
#
#                                                  Mult-Adds
# Layer
# 0_conv_blk1.conv1.Conv3d_0                     905.969664M
# 1_conv_blk1.conv1.BatchNorm3d_1                       64.0
# 2_conv_blk1.conv1.ReLU_2                                 -
# 3_conv_blk1.conv2.Conv3d_0                   57.982058496G
# 4_conv_blk1.conv2.BatchNorm3d_1                       64.0
# 5_conv_blk1.conv2.ReLU_2                                 -
# 6_conv_blk1.Conv3d_residual_upsampler           33.554432M
# 7_pool1                                                  -
# 8_conv_blk2.conv1.Conv3d_0                   28.991029248G
# 9_conv_blk2.conv1.BatchNorm3d_1                      256.0
# 10_conv_blk2.conv1.ReLU_2                                -
# 11_conv_blk2.conv2.Conv3d_0                 115.964116992G
# 12_conv_blk2.conv2.BatchNorm3d_1                     256.0
# 13_conv_blk2.conv2.ReLU_2                                -
# 14_conv_blk2.Conv3d_residual_upsampler        1.073741824G
# 15_pool2                                                 -
# 16_conv_blk3.conv1.Conv3d_0                  14.495514624G
# 17_conv_blk3.conv1.BatchNorm3d_1                     256.0
# 18_conv_blk3.conv1.ReLU_2                                -
# 19_conv_blk3.conv2.Conv3d_0                  14.495514624G
# 20_conv_blk3.conv2.BatchNorm3d_1                     256.0
# 21_conv_blk3.conv2.ReLU_2                                -
# 22_conv_blk3.Conv3d_residual_upsampler         536.870912M
# 23_pool3                                                 -
# 24_conv_blk4.conv1.Conv3d_0                   3.623878656G
# 25_conv_blk4.conv1.BatchNorm3d_1                     512.0
# 26_conv_blk4.conv1.ReLU_2                                -
# 27_conv_blk4.conv2.Conv3d_0                   7.247757312G
# 28_conv_blk4.conv2.BatchNorm3d_1                     512.0
# 29_conv_blk4.conv2.ReLU_2                                -
# 30_conv_blk4.Conv3d_residual_upsampler         134.217728M
# 31_pool4                                                 -
# 32_conv_blk5.conv1.Conv3d_0                   1.811939328G
# 33_conv_blk5.conv1.BatchNorm3d_1                    1.024k
# 34_conv_blk5.conv1.ReLU_2                                -
# 35_conv_blk5.conv2.Conv3d_0                   3.623878656G
# 36_conv_blk5.conv2.BatchNorm3d_1                    1.024k
# 37_conv_blk5.conv2.ReLU_2                                -
# 38_conv_blk5.Conv3d_residual_upsampler          67.108864M
# 39_deconv_blk4.deconv.ConvTranspose3d_0      14.495514624G
# 40_deconv_blk4.deconv.ReLU_1                             -
# 41_dec_conv_blk4.conv1.Conv3d_0              14.495514624G
# 42_dec_conv_blk4.conv1.BatchNorm3d_1                 512.0
# 43_dec_conv_blk4.conv1.ReLU_2                            -
# 44_dec_conv_blk4.conv2.Conv3d_0               7.247757312G
# 45_dec_conv_blk4.conv2.BatchNorm3d_1                 512.0
# 46_dec_conv_blk4.conv2.ReLU_2                            -
# 47_dec_conv_blk4.Conv3d_residual_upsampler     536.870912M
# 48_deconv_blk3.deconv.ConvTranspose3d_0      28.991029248G
# 49_deconv_blk3.deconv.ReLU_1                             -
# 50_dec_conv_blk3.conv1.Conv3d_0              28.991029248G
# 51_dec_conv_blk3.conv1.BatchNorm3d_1                 256.0
# 52_dec_conv_blk3.conv1.ReLU_2                            -
# 53_dec_conv_blk3.conv2.Conv3d_0              14.495514624G
# 54_dec_conv_blk3.conv2.BatchNorm3d_1                 256.0
# 55_dec_conv_blk3.conv2.ReLU_2                            -
# 56_dec_conv_blk3.Conv3d_residual_upsampler    1.073741824G
# 57_deconv_blk2.deconv.ConvTranspose3d_0     115.964116992G
# 58_deconv_blk2.deconv.ReLU_1                             -
# 59_dec_conv_blk2.conv1.Conv3d_0             231.928233984G
# 60_dec_conv_blk2.conv1.BatchNorm3d_1                 256.0
# 61_dec_conv_blk2.conv1.ReLU_2                            -
# 62_dec_conv_blk2.conv2.Conv3d_0             115.964116992G
# 63_dec_conv_blk2.conv2.BatchNorm3d_1                 256.0
# 64_dec_conv_blk2.conv2.ReLU_2                            -
# 65_dec_conv_blk2.Conv3d_residual_upsampler    8.589934592G
# 66_deconv_blk1.deconv.ConvTranspose3d_0     231.928233984G
# 67_deconv_blk1.deconv.ReLU_1                             -
# 68_dec_conv_blk1.conv1.Conv3d_0             115.964116992G
# 69_dec_conv_blk1.conv1.BatchNorm3d_1                  64.0
# 70_dec_conv_blk1.conv1.ReLU_2                            -
# 71_dec_conv_blk1.conv2.Conv3d_0              57.982058496G
# 72_dec_conv_blk1.conv2.BatchNorm3d_1                  64.0
# 73_dec_conv_blk1.conv2.ReLU_2                            -
# 74_dec_conv_blk1.Conv3d_residual_upsampler    4.294967296G
# 75_one_conv                                     33.554432M
# 76_sigmoid                                               -
# ------------------------------------------------------------------------------------------------------------------
#                                Totals
# Total params              112.588417M
# Trainable params          112.588417M
# Non-trainable params              0.0
# Mult-Adds             1.243963463936T
# ==================================================================================================================
# out size: torch.Size([1, 1, 128, 128, 32])
# /usr/local/lib/python3.7/dist-packages/torchsummaryX/torchsummaryX.py:101: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_sum = df.sum()

# %%
if a is not None:
  del a
if model is not None:
  del model
torch.cuda.empty_cache() #doesn't seem to work in interpreter

# %%
model = UNet().cuda()

# %%
a = torch.randn(32,1,32,32,32).cuda()

# %%
model(a)
# Out:
# x torch.Size([32, 1, 32, 32, 32])
# x1 torch.Size([32, 64, 32, 32, 32])
# x2 torch.Size([32, 256, 16, 16, 16])
# x3 torch.Size([32, 256, 8, 8, 8])
# x4 torch.Size([32, 512, 4, 4, 4])
# d_high4 torch.Size([32, 512, 4, 4, 4])
# d_high3 torch.Size([32, 256, 8, 8, 8])
# d_high2 torch.Size([32, 256, 16, 16, 16])
# d_high1 torch.Size([32, 64, 32, 32, 32])
# seg torch.Size([32, 1, 32, 32, 32])
# tensor([[[[[0.4755, 0.4546, 0.3778,  ..., 0.3932, 0.4387, 0.4577],
#            [0.4175, 0.4698, 0.5316,  ..., 0.6231, 0.5316, 0.4928],
#            [0.4419, 0.4782, 0.4976,  ..., 0.3770, 0.4959, 0.4932],
#            ...,
#            [0.4735, 0.4194, 0.4269,  ..., 0.4671, 0.4305, 0.4789],
#            [0.3931, 0.4931, 0.5381,  ..., 0.4995, 0.4135, 0.4868],
#            [0.4188, 0.4978, 0.4611,  ..., 0.4716, 0.5130, 0.4871]],
#
#           [[0.4069, 0.4548, 0.4032,  ..., 0.4490, 0.5219, 0.4814],
#            [0.3981, 0.4024, 0.5689,  ..., 0.4023, 0.4858, 0.4706],
#            [0.4727, 0.5536, 0.4549,  ..., 0.4810, 0.5515, 0.4312],
#            ...,
#            [0.4343, 0.4596, 0.6131,  ..., 0.4779, 0.5491, 0.4269],
#            [0.3957, 0.5134, 0.4575,  ..., 0.5630, 0.4941, 0.4278],
#            [0.5001, 0.3849, 0.4856,  ..., 0.3006, 0.5770, 0.4633]],
#
#           [[0.4506, 0.5048, 0.4504,  ..., 0.4382, 0.4448, 0.3808],
#            [0.5202, 0.4204, 0.4707,  ..., 0.5994, 0.5227, 0.4234],
#            [0.4913, 0.4208, 0.6086,  ..., 0.3883, 0.4550, 0.4748],
#            ...,
#            [0.5371, 0.5227, 0.6398,  ..., 0.6349, 0.4069, 0.4949],
#            [0.4441, 0.5379, 0.5768,  ..., 0.3361, 0.5121, 0.5069],
#            [0.4075, 0.4100, 0.5608,  ..., 0.4433, 0.5235, 0.5203]],
#
#           ...,
#
#           [[0.5122, 0.5944, 0.3464,  ..., 0.5103, 0.5025, 0.5264],
#            [0.5593, 0.4978, 0.5716,  ..., 0.6216, 0.4265, 0.4093],
#            [0.3215, 0.6101, 0.4385,  ..., 0.6135, 0.5890, 0.6160],
#            ...,
#            [0.3932, 0.4920, 0.5527,  ..., 0.4826, 0.5899, 0.5506],
#            [0.4679, 0.6275, 0.6079,  ..., 0.4232, 0.4027, 0.4819],
#            [0.4844, 0.5411, 0.4403,  ..., 0.3711, 0.4277, 0.4695]],
#
#           [[0.4412, 0.4491, 0.5005,  ..., 0.4526, 0.4006, 0.4174],
#            [0.4377, 0.6487, 0.4383,  ..., 0.5066, 0.5414, 0.4412],
#            [0.4130, 0.4418, 0.4843,  ..., 0.5786, 0.6170, 0.6054],
#            ...,
#            [0.4680, 0.5102, 0.4509,  ..., 0.5158, 0.5725, 0.5571],
#            [0.4583, 0.5048, 0.5087,  ..., 0.4444, 0.4814, 0.4702],
#            [0.3688, 0.5755, 0.4219,  ..., 0.4841, 0.4009, 0.4875]],
#
#           [[0.4819, 0.3748, 0.5406,  ..., 0.4258, 0.3673, 0.5175],
#            [0.5151, 0.5361, 0.4904,  ..., 0.5637, 0.4981, 0.4156],
#            [0.4094, 0.5609, 0.5597,  ..., 0.3728, 0.4210, 0.3886],
#            ...,
#            [0.4514, 0.5160, 0.3996,  ..., 0.5054, 0.4478, 0.3889],
#            [0.4451, 0.5656, 0.4222,  ..., 0.4528, 0.4991, 0.4561],
#            [0.4572, 0.4101, 0.4031,  ..., 0.4590, 0.5039, 0.3954]]]],
#
#
#
#         [[[[0.4232, 0.4749, 0.4961,  ..., 0.4256, 0.4482, 0.4379],
#            [0.4180, 0.4399, 0.4178,  ..., 0.4458, 0.4209, 0.5207],
#            [0.4028, 0.4501, 0.4780,  ..., 0.4929, 0.5313, 0.4731],
#            ...,
#            [0.4643, 0.5022, 0.4298,  ..., 0.4058, 0.5382, 0.4811],
#            [0.4789, 0.4771, 0.5810,  ..., 0.4600, 0.4453, 0.5809],
#            [0.3897, 0.4163, 0.5182,  ..., 0.4428, 0.5420, 0.5020]],
#
#           [[0.4462, 0.4117, 0.4545,  ..., 0.3737, 0.4572, 0.5224],
#            [0.5089, 0.5385, 0.6436,  ..., 0.6228, 0.5492, 0.4511],
#            [0.3688, 0.5187, 0.4587,  ..., 0.4222, 0.2990, 0.4468],
#            ...,
#            [0.5084, 0.5366, 0.5286,  ..., 0.6658, 0.5925, 0.5219],
#            [0.3564, 0.4674, 0.5469,  ..., 0.4602, 0.4713, 0.3768],
#            [0.3396, 0.3554, 0.4439,  ..., 0.3968, 0.5583, 0.3798]],
#
#           [[0.4410, 0.4351, 0.4715,  ..., 0.4350, 0.4208, 0.5038],
#            [0.4428, 0.3606, 0.4576,  ..., 0.4076, 0.6208, 0.4665],
#            [0.4684, 0.5492, 0.6131,  ..., 0.6354, 0.5669, 0.4393],
#            ...,
#            [0.4371, 0.5941, 0.4275,  ..., 0.3527, 0.5707, 0.6186],
#            [0.3759, 0.5019, 0.5310,  ..., 0.5287, 0.4309, 0.5743],
#            [0.3550, 0.4191, 0.5323,  ..., 0.4702, 0.4825, 0.3790]],
#
#           ...,
#
#           [[0.4702, 0.3818, 0.3934,  ..., 0.5117, 0.4421, 0.4679],
#            [0.3863, 0.5576, 0.3423,  ..., 0.4597, 0.4198, 0.4706],
#            [0.4502, 0.4222, 0.5680,  ..., 0.5430, 0.5031, 0.4543],
#            ...,
#            [0.4108, 0.6396, 0.5683,  ..., 0.6327, 0.4134, 0.6304],
#            [0.4450, 0.3133, 0.4691,  ..., 0.5034, 0.4191, 0.5018],
#            [0.5054, 0.5523, 0.4801,  ..., 0.4831, 0.4659, 0.4932]],
#
#           [[0.4333, 0.4710, 0.4261,  ..., 0.4141, 0.4359, 0.4637],
#            [0.4426, 0.5441, 0.3726,  ..., 0.4525, 0.4623, 0.4507],
#            [0.2888, 0.4503, 0.5310,  ..., 0.3900, 0.4687, 0.5361],
#            ...,
#            [0.4484, 0.3759, 0.4541,  ..., 0.5083, 0.4176, 0.5048],
#            [0.5173, 0.5668, 0.4381,  ..., 0.4364, 0.3786, 0.6115],
#            [0.3622, 0.5977, 0.4835,  ..., 0.4879, 0.5142, 0.4845]],
#
#           [[0.4455, 0.4991, 0.4187,  ..., 0.4240, 0.3934, 0.4917],
#            [0.4110, 0.5113, 0.4548,  ..., 0.5915, 0.3995, 0.4623],
#            [0.3875, 0.4565, 0.3617,  ..., 0.5196, 0.4530, 0.4180],
#            ...,
#            [0.4267, 0.5884, 0.4787,  ..., 0.3504, 0.4864, 0.5219],
#            [0.4304, 0.5327, 0.5693,  ..., 0.3910, 0.4072, 0.4577],
#            [0.3361, 0.4181, 0.4076,  ..., 0.3819, 0.4102, 0.3853]]]],
#
#
#
#         [[[[0.4131, 0.4658, 0.5209,  ..., 0.4328, 0.4533, 0.5196],
#            [0.4641, 0.5037, 0.5008,  ..., 0.5340, 0.4728, 0.4663],
#            [0.5223, 0.5278, 0.5837,  ..., 0.5429, 0.4908, 0.4982],
#            ...,
#            [0.4443, 0.4588, 0.5259,  ..., 0.4123, 0.4633, 0.4064],
#            [0.4238, 0.5546, 0.5004,  ..., 0.5293, 0.4831, 0.5544],
#            [0.4347, 0.4615, 0.4235,  ..., 0.5311, 0.4803, 0.4480]],
#
#           [[0.4600, 0.4821, 0.4418,  ..., 0.5414, 0.4235, 0.5709],
#            [0.4474, 0.5108, 0.4456,  ..., 0.5703, 0.6158, 0.4503],
#            [0.4877, 0.6494, 0.5587,  ..., 0.4859, 0.6303, 0.3849],
#            ...,
#            [0.3910, 0.6190, 0.6923,  ..., 0.6049, 0.3415, 0.5774],
#            [0.3961, 0.4705, 0.4286,  ..., 0.4283, 0.4170, 0.4611],
#            [0.4628, 0.3669, 0.3538,  ..., 0.3950, 0.5596, 0.3524]],
#
#           [[0.4601, 0.4532, 0.5301,  ..., 0.5155, 0.4819, 0.4035],
#            [0.4530, 0.5941, 0.4639,  ..., 0.6241, 0.3912, 0.4019],
#            [0.4721, 0.6244, 0.5752,  ..., 0.4011, 0.3920, 0.4706],
#            ...,
#            [0.5161, 0.4989, 0.5745,  ..., 0.5168, 0.4551, 0.6384],
#            [0.4270, 0.5962, 0.5917,  ..., 0.5859, 0.4175, 0.4564],
#            [0.4233, 0.6037, 0.3726,  ..., 0.3746, 0.4546, 0.4185]],
#
#           ...,
#
#           [[0.3843, 0.4666, 0.4442,  ..., 0.3904, 0.4605, 0.4466],
#            [0.4990, 0.6411, 0.5420,  ..., 0.6093, 0.5242, 0.4992],
#            [0.4389, 0.3779, 0.6053,  ..., 0.4562, 0.4706, 0.4968],
#            ...,
#            [0.5034, 0.4646, 0.5824,  ..., 0.4956, 0.4997, 0.5062],
#            [0.4474, 0.4380, 0.4775,  ..., 0.5233, 0.5024, 0.4742],
#            [0.5409, 0.5304, 0.3831,  ..., 0.4212, 0.4181, 0.4799]],
#
#           [[0.4577, 0.4833, 0.5033,  ..., 0.4351, 0.4258, 0.5268],
#            [0.3836, 0.4529, 0.4407,  ..., 0.6717, 0.5156, 0.4337],
#            [0.3902, 0.5788, 0.4372,  ..., 0.5100, 0.4294, 0.4950],
#            ...,
#            [0.5231, 0.5209, 0.5350,  ..., 0.5538, 0.6447, 0.5455],
#            [0.4796, 0.6352, 0.5524,  ..., 0.6653, 0.4608, 0.5207],
#            [0.4131, 0.4200, 0.4171,  ..., 0.4161, 0.4152, 0.3424]],
#
#           [[0.4249, 0.4767, 0.4444,  ..., 0.5014, 0.4119, 0.5141],
#            [0.5533, 0.4817, 0.5628,  ..., 0.4955, 0.3917, 0.5546],
#            [0.4521, 0.3785, 0.4968,  ..., 0.5026, 0.5070, 0.4834],
#            ...,
#            [0.4181, 0.5797, 0.5147,  ..., 0.5011, 0.4746, 0.5376],
#            [0.4091, 0.5163, 0.3418,  ..., 0.5257, 0.5669, 0.4935],
#            [0.4581, 0.4902, 0.4146,  ..., 0.4287, 0.3940, 0.4328]]]],
#
#
#
#         ...,
#
#
#
#         [[[[0.4873, 0.4149, 0.4469,  ..., 0.4811, 0.4821, 0.4735],
#            [0.4852, 0.4889, 0.5314,  ..., 0.4431, 0.5655, 0.4614],
#            [0.4688, 0.3901, 0.3580,  ..., 0.5259, 0.5184, 0.4999],
#            ...,
#            [0.4565, 0.5517, 0.3832,  ..., 0.5725, 0.4694, 0.4671],
#            [0.5378, 0.5343, 0.5756,  ..., 0.4096, 0.4183, 0.4864],
#            [0.4190, 0.5188, 0.4846,  ..., 0.5138, 0.5304, 0.5151]],
#
#           [[0.3909, 0.4764, 0.4415,  ..., 0.4516, 0.4067, 0.5164],
#            [0.3808, 0.4258, 0.6034,  ..., 0.6130, 0.4616, 0.4501],
#            [0.4183, 0.6458, 0.4494,  ..., 0.5335, 0.5660, 0.5361],
#            ...,
#            [0.4636, 0.4607, 0.4814,  ..., 0.4557, 0.4470, 0.4816],
#            [0.5028, 0.4175, 0.5086,  ..., 0.4240, 0.4081, 0.4842],
#            [0.4339, 0.4204, 0.4362,  ..., 0.4337, 0.4268, 0.4581]],
#
#           [[0.4654, 0.4824, 0.4547,  ..., 0.5048, 0.3885, 0.4036],
#            [0.4704, 0.6319, 0.6025,  ..., 0.5163, 0.4537, 0.5369],
#            [0.4533, 0.4223, 0.5369,  ..., 0.4721, 0.4578, 0.6183],
#            ...,
#            [0.3637, 0.5650, 0.5529,  ..., 0.5508, 0.3871, 0.5474],
#            [0.5107, 0.6324, 0.5265,  ..., 0.6084, 0.5117, 0.4752],
#            [0.3790, 0.4028, 0.2832,  ..., 0.5164, 0.4619, 0.3946]],
#
#           ...,
#
#           [[0.4255, 0.5026, 0.4218,  ..., 0.4064, 0.4201, 0.4934],
#            [0.4506, 0.5170, 0.5933,  ..., 0.5811, 0.3796, 0.4809],
#            [0.4387, 0.5439, 0.4262,  ..., 0.4729, 0.3979, 0.4874],
#            ...,
#            [0.3783, 0.3075, 0.4365,  ..., 0.5149, 0.5459, 0.4665],
#            [0.5670, 0.5123, 0.6846,  ..., 0.4312, 0.4416, 0.3795],
#            [0.4105, 0.5021, 0.5985,  ..., 0.4731, 0.5686, 0.4936]],
#
#           [[0.4226, 0.4975, 0.4079,  ..., 0.4455, 0.4191, 0.4825],
#            [0.4357, 0.5888, 0.4796,  ..., 0.3619, 0.4710, 0.5468],
#            [0.2736, 0.4819, 0.3428,  ..., 0.6134, 0.4280, 0.5718],
#            ...,
#            [0.4120, 0.4280, 0.5237,  ..., 0.4769, 0.4255, 0.4507],
#            [0.3681, 0.5847, 0.5520,  ..., 0.3822, 0.4785, 0.4914],
#            [0.4508, 0.5844, 0.4437,  ..., 0.5128, 0.4567, 0.3558]],
#
#           [[0.4738, 0.5105, 0.4948,  ..., 0.4806, 0.4153, 0.4860],
#            [0.5022, 0.4890, 0.4009,  ..., 0.4804, 0.5185, 0.4809],
#            [0.3298, 0.5116, 0.4314,  ..., 0.3968, 0.5226, 0.5036],
#            ...,
#            [0.4437, 0.5203, 0.4602,  ..., 0.3739, 0.3481, 0.4587],
#            [0.4521, 0.4352, 0.3842,  ..., 0.3681, 0.4179, 0.5286],
#            [0.3711, 0.4012, 0.3662,  ..., 0.4952, 0.3816, 0.4994]]]],
#
#
#
#         [[[[0.4162, 0.4428, 0.4208,  ..., 0.4619, 0.4688, 0.4457],
#            [0.3015, 0.4878, 0.4948,  ..., 0.4811, 0.4127, 0.5220],
#            [0.3738, 0.4590, 0.5323,  ..., 0.5113, 0.3783, 0.4675],
#            ...,
#            [0.3354, 0.3516, 0.4250,  ..., 0.5128, 0.4964, 0.4811],
#            [0.4545, 0.5472, 0.4535,  ..., 0.5308, 0.5132, 0.4284],
#            [0.4207, 0.4412, 0.4680,  ..., 0.5671, 0.5081, 0.4669]],
#
#           [[0.4376, 0.4933, 0.4309,  ..., 0.4556, 0.4820, 0.5165],
#            [0.4483, 0.4865, 0.4992,  ..., 0.5817, 0.4877, 0.4769],
#            [0.4920, 0.4506, 0.5106,  ..., 0.5537, 0.4967, 0.4988],
#            ...,
#            [0.3652, 0.4064, 0.5019,  ..., 0.4414, 0.5002, 0.5958],
#            [0.4777, 0.4422, 0.4449,  ..., 0.5775, 0.4248, 0.5456],
#            [0.3930, 0.4626, 0.4423,  ..., 0.6370, 0.5654, 0.4356]],
#
#           [[0.4171, 0.3995, 0.4110,  ..., 0.4591, 0.3580, 0.4672],
#            [0.4958, 0.3480, 0.5955,  ..., 0.5345, 0.4029, 0.4854],
#            [0.4679, 0.3733, 0.3799,  ..., 0.5269, 0.4167, 0.5311],
#            ...,
#            [0.4557, 0.4268, 0.4206,  ..., 0.5057, 0.6191, 0.4836],
#            [0.4029, 0.4693, 0.5300,  ..., 0.5500, 0.5302, 0.4931],
#            [0.3859, 0.3731, 0.4969,  ..., 0.4290, 0.4279, 0.3761]],
#
#           ...,
#
#           [[0.3998, 0.4934, 0.3465,  ..., 0.5589, 0.4210, 0.5145],
#            [0.3742, 0.5383, 0.3783,  ..., 0.6143, 0.3527, 0.5606],
#            [0.3463, 0.4837, 0.4492,  ..., 0.6026, 0.4674, 0.4320],
#            ...,
#            [0.4917, 0.4466, 0.5378,  ..., 0.5042, 0.4130, 0.5460],
#            [0.4581, 0.5593, 0.5545,  ..., 0.4928, 0.4009, 0.5124],
#            [0.3539, 0.5125, 0.5052,  ..., 0.4847, 0.5280, 0.3993]],
#
#           [[0.3790, 0.4895, 0.4356,  ..., 0.4769, 0.4030, 0.4022],
#            [0.4238, 0.4783, 0.4345,  ..., 0.4246, 0.4994, 0.4344],
#            [0.4255, 0.4441, 0.3850,  ..., 0.5169, 0.4247, 0.5324],
#            ...,
#            [0.3741, 0.3402, 0.5977,  ..., 0.5269, 0.4954, 0.4389],
#            [0.4576, 0.5102, 0.4534,  ..., 0.5551, 0.5691, 0.5091],
#            [0.4133, 0.4628, 0.3802,  ..., 0.4742, 0.4808, 0.4603]],
#
#           [[0.4445, 0.4979, 0.4981,  ..., 0.5867, 0.5098, 0.5673],
#            [0.4648, 0.4208, 0.5074,  ..., 0.5130, 0.4580, 0.4613],
#            [0.4213, 0.3894, 0.4163,  ..., 0.4672, 0.4844, 0.4913],
#            ...,
#            [0.4058, 0.5229, 0.5527,  ..., 0.4982, 0.5061, 0.4159],
#            [0.4407, 0.3294, 0.4216,  ..., 0.4535, 0.4822, 0.5102],
#            [0.4513, 0.4209, 0.2672,  ..., 0.4681, 0.4066, 0.4227]]]],
#
#
#
#         [[[[0.4634, 0.3904, 0.4829,  ..., 0.4377, 0.4406, 0.5164],
#            [0.3639, 0.4917, 0.4732,  ..., 0.4547, 0.4945, 0.4810],
#            [0.5080, 0.5185, 0.4898,  ..., 0.4780, 0.4425, 0.4907],
#            ...,
#            [0.3826, 0.5315, 0.5106,  ..., 0.4842, 0.4725, 0.4164],
#            [0.5183, 0.4339, 0.5226,  ..., 0.5253, 0.4476, 0.4595],
#            [0.4079, 0.4762, 0.4225,  ..., 0.4906, 0.4795, 0.3951]],
#
#           [[0.4552, 0.4123, 0.3479,  ..., 0.5143, 0.4147, 0.4020],
#            [0.4389, 0.4090, 0.4020,  ..., 0.5300, 0.4573, 0.4724],
#            [0.4408, 0.6136, 0.3845,  ..., 0.5674, 0.3974, 0.5347],
#            ...,
#            [0.5294, 0.7060, 0.5110,  ..., 0.4985, 0.5243, 0.4954],
#            [0.3761, 0.5569, 0.5041,  ..., 0.4867, 0.6172, 0.5250],
#            [0.4692, 0.4186, 0.4228,  ..., 0.4573, 0.4879, 0.3983]],
#
#           [[0.5086, 0.4854, 0.4969,  ..., 0.4708, 0.3683, 0.5682],
#            [0.4518, 0.6554, 0.3383,  ..., 0.4932, 0.3902, 0.3706],
#            [0.4381, 0.4010, 0.6025,  ..., 0.4903, 0.4589, 0.5442],
#            ...,
#            [0.5133, 0.4943, 0.5536,  ..., 0.6149, 0.5585, 0.4901],
#            [0.4652, 0.4519, 0.4773,  ..., 0.4931, 0.3339, 0.4911],
#            [0.3848, 0.4544, 0.3853,  ..., 0.3468, 0.4588, 0.3994]],
#
#           ...,
#
#           [[0.4759, 0.4422, 0.4005,  ..., 0.4560, 0.5434, 0.4139],
#            [0.4646, 0.3729, 0.4928,  ..., 0.4412, 0.3253, 0.4883],
#            [0.4694, 0.5474, 0.4898,  ..., 0.4855, 0.4502, 0.4980],
#            ...,
#            [0.4015, 0.4075, 0.4731,  ..., 0.4247, 0.4613, 0.5512],
#            [0.4696, 0.5368, 0.6759,  ..., 0.5344, 0.5164, 0.5512],
#            [0.4326, 0.4966, 0.5457,  ..., 0.4963, 0.4590, 0.6268]],
#
#           [[0.4205, 0.4363, 0.4357,  ..., 0.5131, 0.4800, 0.4847],
#            [0.3514, 0.4932, 0.5664,  ..., 0.5066, 0.4167, 0.4479],
#            [0.4156, 0.4427, 0.5705,  ..., 0.4551, 0.5036, 0.5709],
#            ...,
#            [0.3631, 0.5146, 0.5007,  ..., 0.5161, 0.4956, 0.5016],
#            [0.4501, 0.6008, 0.5787,  ..., 0.3035, 0.6115, 0.5221],
#            [0.4516, 0.4726, 0.4328,  ..., 0.4492, 0.4188, 0.5455]],
#
#           [[0.4277, 0.4934, 0.5149,  ..., 0.4580, 0.4073, 0.4610],
#            [0.4178, 0.3912, 0.4215,  ..., 0.4514, 0.4271, 0.4274],
#            [0.4850, 0.5252, 0.4839,  ..., 0.5557, 0.4504, 0.5442],
#            ...,
#            [0.4614, 0.4732, 0.5090,  ..., 0.4754, 0.4861, 0.4936],
#            [0.4104, 0.4880, 0.4243,  ..., 0.4933, 0.3898, 0.4522],
#            [0.4691, 0.5127, 0.4058,  ..., 0.4590, 0.3780, 0.3785]]]]],
#        device='cuda:0', grad_fn=<SigmoidBackward0>)
